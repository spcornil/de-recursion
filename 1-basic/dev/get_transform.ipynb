# %%
import json
import pandas as pd
import requests as rq
from datetime import datetime as dt

# %%
# See the following for data source
# https://openskynetwork.github.io/opensky-api/rest.html

url = 'https://opensky-network.org/api/states/all'

# %%
response = rq.get(url)
data = response.json()
df = pd.json_normalize(data)

# %%
df.head(20)
# Out:
#          time                                             states
# 0  1678342906  [[407a38, NPT902  , United Kingdom, 1678342906...

# %%
# Prints out 'pretty' json - will help with normalization
# Commenting out for now as this will print ALL several thousand lines
# print(json.dumps(data, indent=4))

# %%
df2 = pd.json_normalize(data, 'states')
df2.head(10)
# Out:
#        0         1               2             3           4         5   \
# 0  407a38  NPT902    United Kingdom  1.678343e+09  1678342906   -1.2155
# 1  acdfb1  SIL3967    United States  1.678343e+09  1678342906  -98.9386
# 2  ac4963  DAL955     United States  1.678343e+09  1678342906 -121.0855
# 3  aae316  AAL2343    United States  1.678343e+09  1678342906 -114.2095
# 4  acdfa3  ASA1078    United States  1.678343e+09  1678342906 -123.1822
# 5  3945e8                    France  1.678343e+09  1678342663    8.6358
# 6  851914  JAL3114            Japan  1.678343e+09  1678342905  138.9053
# 7  a0e250  AAL2984    United States  1.678343e+09  1678342906 -122.0749
# 8  a1025a  UPS9306    United States  1.678343e+09  1678342902  -69.3876
# 9  407a06  EZY62EB   United Kingdom  1.678343e+09  1678342903   -2.2762
#
#         6         7      8       9       10     11    12        13    14  \
# 0  52.1205   4884.42  False  132.75  181.11   0.00  None   4678.68  1252
# ...

# %%
# Update column names according to OpenSky standardized col names
df2.columns = ['icao24'
              ,'callsign'
              ,'origin_country'
              ,'time_position'
              ,'last_contact'
              ,'longitude'
              ,'latitude'
              ,'baro_altitude'
              ,'on_ground'
              ,'velocity'
              ,'true_track'
              ,'vertical_rate'
              ,'sensors'
              ,'geo_altitude'
              ,'squawk'
              ,'spi'
              ,'position_source'
              ]
df2.head(10)
# Out:
#    icao24  callsign  origin_country  time_position  last_contact  longitude  \
# 0  407a38  NPT902    United Kingdom   1.678343e+09    1678342906    -1.2155
# 1  acdfb1  SIL3967    United States   1.678343e+09    1678342906   -98.9386
# 2  ac4963  DAL955     United States   1.678343e+09    1678342906  -121.0855
# 3  aae316  AAL2343    United States   1.678343e+09    1678342906  -114.2095
# 4  acdfa3  ASA1078    United States   1.678343e+09    1678342906  -123.1822
# 5  3945e8                    France   1.678343e+09    1678342663     8.6358
# 6  851914  JAL3114            Japan   1.678343e+09    1678342905   138.9053
# 7  a0e250  AAL2984    United States   1.678343e+09    1678342906  -122.0749
# 8  a1025a  UPS9306    United States   1.678343e+09    1678342902   -69.3876
# 9  407a06  EZY62EB   United Kingdom   1.678343e+09    1678342903    -2.2762
#
#    latitude  baro_altitude  on_ground  velocity  true_track  vertical_rate  \
# ...

# %%
# Make a copy of df2
df3 = df2

# Originally filled in NaN to relieve some issues with transformations
# Went back and left as NaN as nulls are perfectly fine in dataset
# df3 = df2.fillna(-1)

# %%
df3.dtypes
# Out:
# icao24              object
# callsign            object
# origin_country      object
# time_position      float64
# last_contact         int64
# longitude          float64
# latitude           float64
# baro_altitude      float64
# on_ground             bool
# velocity           float64
# true_track         float64
# vertical_rate      float64
# sensors             object
# geo_altitude       float64
# squawk              object
# spi                   bool
# position_source      int64
# dtype: object

# %%
# Convert epoch time to datetime
#df3['time_position'].astype('int').astype("datetime64[s]")
df3['time_position'].astype("datetime64[s]")
# Out:
# 0      2023-03-09 06:21:46
# 1      2023-03-09 06:21:46
# 2      2023-03-09 06:21:46
# 3      2023-03-09 06:21:46
# 4      2023-03-09 06:21:46
#                ...
# 4254   2023-03-09 06:21:45
# 4255   2023-03-09 06:21:46
# 4256   2023-03-09 06:21:45
# 4257   2023-03-09 06:21:45
# 4258   2023-03-09 06:21:45
# Name: time_position, Length: 4259, dtype: datetime64[ns]

# %%
df3['time_position'] = df3['time_position'].astype("datetime64[s]")
df3['last_contact'] = df3['last_contact'].astype("datetime64[s]")

# %%
df3
# Out:
#       icao24  callsign  origin_country       time_position  \
# 0     407a38  NPT902    United Kingdom 2023-03-09 06:21:46
# 1     acdfb1  SIL3967    United States 2023-03-09 06:21:46
# 2     ac4963  DAL955     United States 2023-03-09 06:21:46
# 3     aae316  AAL2343    United States 2023-03-09 06:21:46
# 4     acdfa3  ASA1078    United States 2023-03-09 06:21:46
# ...      ...       ...             ...                 ...
# 4254  4b1916  SWR93        Switzerland 2023-03-09 06:21:45
# 4255  4b1918  SWR33P       Switzerland 2023-03-09 06:21:46
# 4256  aaa0f3  N784SA     United States 2023-03-09 06:21:45
# 4257  4b1903  SWR135       Switzerland 2023-03-09 06:21:45
# 4258  a4358d  OUA37      United States 2023-03-09 06:21:45
#
#             last_contact  longitude  latitude  baro_altitude  on_ground  \
# 0    2023-03-09 06:21:46    -1.2155   52.1205        4884.42      False
# 1    2023-03-09 06:21:46   -98.9386   33.3855        6103.62      False
# ...
